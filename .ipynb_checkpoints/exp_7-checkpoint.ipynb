# %%
import matplotlib.pyplot as plt #visulization
from sklearn import datasets #pre-prepared dataset that we can directly use
from sklearn import svm 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    confusion_matrix,
)
import numpy as np
digits = datasets.load_digits()
X=digits.data
y=digits.target
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
clf = svm.SVC(gamma=0.001, C=100)
clf.fit(X_train, y_train)
y_pred=clf.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [7 7]
#  [3 3]
#  [4 4]
#  [8 8]
#  [9 9]
#  [7 7]
#  [9 9]
#  [8 8]
#  [2 2]
#  [6 6]
#  [5 5]
#  [2 2]
#  [5 5]
#  [8 8]
#  [4 4]
#  [1 8]
#  [7 7]
#  [0 0]
#  [6 6]
#  [1 1]
#  [5 5]
#  [5 9]
#  [9 9]
#  [9 9]
#  [5 5]
#  [9 9]
#  [9 9]
#  [5 5]
#  [7 7]
#  [5 5]
#  [6 6]
#  [2 2]
#  [8 8]
#  [6 6]
#  [9 9]
#  [6 6]
#  [1 1]
#  [5 5]
#  [1 1]
#  [5 5]
#  [9 9]
#  [9 9]
#  [1 1]
#  [5 5]
#  [3 3]
#  [6 6]
#  [1 1]
#  [8 8]
#  [9 9]
#  [8 8]
#  [7 7]
#  [6 6]
#  [7 7]
#  [6 6]
#  [5 5]
#  [6 6]
#  [0 0]
#  [8 8]
#  [8 8]
#  [9 9]
#  [8 8]
#  [6 6]
#  [1 1]
#  [0 0]
#  [4 4]
#  [1 1]
#  [6 6]
#  [3 3]
#  [8 8]
#  [6 6]
#  [7 7]
#  [4 4]
#  [9 5]
#  [6 6]
#  [3 3]
#  [0 0]
#  [3 3]
#  [3 3]
#  [3 3]
#  [0 0]
#  [7 7]
#  [7 7]
#  [5 5]
#  [7 7]
#  [8 8]
#  [0 0]
#  [7 7]
#  [8 8]
#  [9 9]
#  [6 6]
#  [4 4]
#  [5 5]
#  [0 0]
#  [1 1]
#  [4 4]
#  [6 6]
#  [4 4]
#  [3 3]
#  [3 3]
#  [0 0]
#  [9 9]
#  [5 5]
#  [9 9]
#  [2 2]
#  [1 1]
#  [4 4]
#  [2 2]
#  [1 1]
#  [6 6]
#  [8 8]
#  [9 9]
#  [2 2]
#  [4 4]
#  [9 9]
#  [3 3]
#  [7 7]
#  [6 6]
#  [2 2]
#  [3 3]
#  [3 3]
#  [1 1]
#  [6 6]
#  [9 9]
#  [3 3]
#  [6 6]
#  [3 3]
#  [2 2]
#  [2 2]
#  [0 0]
#  [7 7]
#  [6 6]
#  [1 1]
#  [1 1]
#  [9 9]
#  [7 7]
#  [2 2]
#  [7 7]
#  [8 8]
#  [5 5]
#  [5 5]
#  [7 7]
#  [5 5]
#  [2 2]
#  [3 3]
#  [7 7]
#  [2 2]
#  [7 7]
#  [5 5]
#  [5 5]
#  [7 7]
#  [0 0]
#  [9 9]
#  [1 1]
#  [6 6]
#  [5 5]
#  [9 9]
#  [7 7]
#  [4 4]
#  [3 3]
#  [8 8]
#  [0 0]
#  [3 3]
#  [6 6]
#  [4 4]
#  [6 6]
#  [3 3]
#  [2 2]
#  [6 6]
#  [8 8]
#  [8 8]
#  [8 8]
#  [4 4]
#  [6 6]
#  [7 7]
#  [5 5]
#  [2 2]
#  [4 4]
#  [5 5]
#  [3 3]
#  [2 2]
#  [4 4]
#  [6 6]
#  [9 9]
#  [4 4]
#  [5 5]
#  [4 4]
#  [3 3]
#  [4 4]
#  [6 6]
#  [2 2]
#  [9 9]
#  [0 0]
#  [1 1]
#  [7 7]
#  [2 2]
#  [0 0]
#  [9 9]
#  [6 6]
#  [0 0]
#  [4 4]
#  [2 2]
#  [0 0]
#  [7 7]
#  [9 9]
#  [8 8]
#  [5 5]
#  [4 4]
#  [8 8]
#  [2 2]
#  [8 8]
#  [4 4]
#  [3 3]
#  [7 7]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [5 5]
#  [1 1]
#  [0 0]
#  [8 8]
#  [2 2]
#  [1 1]
#  [9 9]
#  [5 5]
#  [6 6]
#  [8 8]
#  [2 2]
#  [7 7]
#  [2 2]
#  [1 1]
#  [5 5]
#  [1 1]
#  [6 6]
#  [4 4]
#  [5 5]
#  [0 0]
#  [9 9]
#  [4 4]
#  [1 1]
#  [1 1]
#  [7 7]
#  [0 0]
#  [8 8]
#  [9 9]
#  [0 0]
#  [5 5]
#  [4 4]
#  [3 3]
#  [8 8]
#  [8 8]
#  [6 6]
#  [5 5]
#  [3 3]
#  [4 4]
#  [4 4]
#  [4 4]
#  [8 8]
#  [8 8]
#  [7 7]
#  [0 0]
#  [9 9]
#  [6 6]
#  [3 3]
#  [5 5]
#  [2 2]
#  [3 3]
#  [0 0]
#  [8 8]
#  [3 3]
#  [3 3]
#  [1 1]
#  [3 3]
#  [3 3]
#  [0 0]
#  [0 0]
#  [4 4]
#  [6 6]
#  [0 0]
#  [7 7]
#  [7 7]
#  [6 6]
#  [2 2]
#  [0 0]
#  [4 4]
#  [4 4]
#  [2 2]
#  [3 3]
#  [7 7]
#  [8 8]
#  [9 9]
#  [8 8]
#  [6 6]
#  [8 8]
#  [5 5]
#  [6 6]
#  [2 2]
#  [2 2]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [8 8]
#  [0 0]
#  [3 3]
#  [3 3]
#  [2 2]
#  [1 1]
#  [5 5]
#  [5 5]
#  [9 9]
#  [1 1]
#  [3 3]
#  [7 7]
#  [0 0]
#  [0 0]
#  [7 7]
#  [0 0]
#  [4 4]
#  [5 5]
#  [9 9]
#  [3 3]
#  [3 3]
#  [4 4]
#  [3 3]
#  [1 1]
#  [8 8]
#  [9 9]
#  [8 8]
#  [3 3]
#  [6 6]
#  [2 2]
#  [1 1]
#  [6 6]
#  [2 2]
#  [1 1]
#  [7 7]
#  [5 5]
#  [5 5]
#  [1 1]
#  [9 9]]

# %%
accuray= accuracy_score(y_pred, y_test)
precision = precision_score(y_pred, y_test, average="weighted")
recall= recall_score(y_pred, y_test, average="weighted")
print("Accuracy_gauss:", accuray)
print("Precision Score_gauss:", precision)
print("recall_guass:", recall)
# Out:
# Accuracy_gauss: 0.9933333333333333
# Precision Score_gauss: 0.9933796296296296
# recall_guass: 0.9933333333333333

# %%
print(clf.predict(digits.data[5].reshape(1, -1)))
plt.imshow(digits.images[5], cmap=plt.cm.gray_r, interpolation='nearest')     
plt.show()
# Out:
# [9]

# %%
print(clf.predict(digits.data[-9].reshape(1, -1)))
plt.imshow(digits.images[-9], cmap=plt.cm.gray_r, interpolation='nearest')     
plt.show()
# Out:
# [4]
